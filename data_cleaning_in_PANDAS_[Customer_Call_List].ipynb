# %% [markdown]
# <a href="https://colab.research.google.com/github/niivveeddiittaa/Data-Analysis-using-PYTHON-EXCEL/blob/main/data_cleaning_in_PANDAS_%5BCustomer_Call_List%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6c7aa0fa-bd4a-42f7-aab4-ea7563980899" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c7aa0fa-bd4a-42f7-aab4-ea7563980899">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('Customer Call List.xlsx')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.shape
# Out:
# (21, 8)

# %% [markdown]
# # **find the percentage of null values present in the columns**

# %%
df.isnull().sum()/df.shape[0]
# Out:
# CustomerID           0.000000
# First_Name           0.000000
# Last_Name            0.047619
# Phone_Number         0.095238
# Address              0.000000
# Paying Customer      0.000000
# Do_Not_Contact       0.190476
# Not_Useful_Column    0.000000
# dtype: float64

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df = df.drop(columns='Not_Useful_Column')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# Working with "Last_Name" column

#df["Last_Name"].str.strip()                           #------------------------------just removes white-spaces

#df["Last_Name"] = df["Last_Name"].str.lstrip("...")   #-----------------------------removes ... from left

#df["Last_Name"] = df["Last_Name"].str.lstrip("/")     #-------------removes / from left

#df["Last_Name"] = df["Last_Name"].str.rstrip("_")     #-------------removes _ from right

#-----------------------OR-------------------------------------

df["Last_Name"] = df["Last_Name"].str.strip("123._/")

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
# Working with "Phone_Number" column
df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]', '', regex=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins     12354554
# 1         1002       Abed       Nadir     12364397
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute     12354323
# 4         1005        Jon        Snow     87667834
# 5         1006        Ron     Swanson     30476224
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes     87667834
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker     12354554
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper     12354323
# 13        1014     Leslie       Knope     87667834
# 14        1015       Toby  Flenderson     30476224
# 15        1016        Ron     Weasley     12354554
# 16        1017   Michael        Scott     12364397
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins     12354554
# 1         1002       Abed       Nadir     12364397
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute     12354323
# 4         1005        Jon        Snow     87667834
# 5         1006        Ron     Swanson     30476224
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes     87667834
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker     12354554
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper     12354323
# 13        1014     Leslie       Knope     87667834
# 14        1015       Toby  Flenderson     30476224
# 15        1016        Ron     Weasley     12354554
# 16        1017   Michael        Scott     12364397
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White           --
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter           --
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('nan--','')
df['Phone_Number'] = df['Phone_Number'].str.replace('Na--','')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White           --
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter           --
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
# working with "Address" columnn

df[["Street_Address", "State", "Zip_Code"]] = df['Address'].str.split(',', expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White           --
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter           --
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
# working with "Paying Customer" column

df['Paying Customer'] = df['Paying Customer'].str.replace('Yes','Y')
df['Paying Customer'] = df['Paying Customer'].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White           --
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter           --
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
# working with "Do_Not_Contact" column

df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes','Y')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White           --
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf         NaN           --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter           --
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
# removing null values

df = df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 1         1002       Abed       Nadir   123-643-97
# 2         1003     Walter       White           --
# 3         1004     Dwight     Schrute   123-543-23
# 4         1005        Jon        Snow   876-678-34
# 5         1006        Ron     Swanson   304-762-24
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf                       --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter           --
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# ...

# %%
# removing rows which says "do_not_call"

for x in df.index:
   if df.loc[x,'Do_Not_Contact'] == 'Y':
      df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 2         1003     Walter       White           --
# 4         1005        Jon        Snow   876-678-34
# 6         1007       Jeff      Winger           --
# 7         1008   Sherlock      Holmes   876-678-34
# 8         1009    Gandalf                       --
# 9         1010      Peter      Parker   123-545-54
# 10        1011    Samwise      Gamgee           --
# 11        1012      Harry      Potter           --
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 17        1018      Clark        Kent           --
# 19        1020     Anakin   Skywalker   876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
# removing rows which donot have columns

for x in df.index:
   if df.loc[x,'Phone_Number'] == '--':
      df.drop(x, inplace=True)

df

#--- if we had ' ' instead of '--'
#df = df.dropna(subset='Phone_Number'),inplace=True)
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   123-545-54
# 4         1005        Jon        Snow   876-678-34
# 7         1008   Sherlock      Holmes   876-678-34
# 9         1010      Peter      Parker   123-545-54
# 12        1013        Don      Draper   123-543-23
# 13        1014     Leslie       Knope   876-678-34
# 14        1015       Toby  Flenderson   304-762-24
# 15        1016        Ron     Weasley   123-545-54
# 16        1017   Michael        Scott   123-643-97
# 19        1020     Anakin   Skywalker   876-678-34
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               Y              N
# 12                2039 Main Street               Y              N
# ...

# %%
 df = df.reset_index(drop=True)
 df
# Out:
#    CustomerID First_Name   Last_Name Phone_Number  \
# 0        1001      Frodo     Baggins   123-545-54
# 1        1005        Jon        Snow   876-678-34
# 2        1008   Sherlock      Holmes   876-678-34
# 3        1010      Peter      Parker   123-545-54
# 4        1013        Don      Draper   123-543-23
# 5        1014     Leslie       Knope   876-678-34
# 6        1015       Toby  Flenderson   304-762-24
# 7        1016        Ron     Weasley   123-545-54
# 8        1017   Michael        Scott   123-643-97
# 9        1020     Anakin   Skywalker   876-678-34
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               Y              N
# 4                2039 Main Street               Y              N
# ...
